# %% [markdown]
# # Regressions

# %%
# Import libraries
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import os
from os import *
import sys
sys.path.append("../")
import urllib.request
import requests
import json
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Change directory
def change_dir(newpath):
    get_path = sys.path[0].split("\\")      
    del get_path[-1]                                                  
    get_path.append(newpath)                    
    path = "\\".join(get_path)              
    os.chdir(path)

# %% [markdown]
# ## Regression 1: Total employment

# %%
change_dir('output//stage2')
data = pd.read_csv("output.csv")
data.columns
# Out:
# Index(['Unnamed: 0', 'area_code', 'hispanic', 'white_nonhispanic',
#        'black_nonhispanic', 'other_nonhispanic', 'asian_nonhispanic',
#        'above_65', 'prepandemic_growth', 'leisure_by_emp', 'total_emp_feb2020',
#        'manufacturing_emp_feb2020', 'service_emp_feb2020', 'total_emp_jun2021',
#        'manufacturing_emp_jun2021', 'service_emp_jun2021', 'total_employment',
#        'manufacturing', 'service', 'emp_tot_change_feb2020_jun2021',
#        'manufacturing_change_feb2020_jun2021',
#        'service_change_feb2020_jun2021', 'occ_15', 'total_pop', 'pop_excl',
#        'less_than_9grade', 'hs_nodiploma', 'ged', 'college_nodegree',
#        'associates', 'bachelors_graduate', 'CBSA Title', 'division', 'region',
#        'state', 'pop_by_metro'],
#       dtype='object')

# %%
# No transformations
x = data[['leisure_by_emp','occ_15','total_pop','bachelors_graduate', 'white_nonhispanic']].copy()
y = data['emp_tot_change_feb2020_jun2021']
model1 = sm.OLS(y,sm.add_constant(x),missing='drop').fit()
print(model1.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     emp_tot_change_feb2020_jun2021   R-squared:                       0.084
# Model:                                        OLS   Adj. R-squared:                  0.069
# Method:                             Least Squares   F-statistic:                     5.741
# Date:                            Wed, 11 Aug 2021   Prob (F-statistic):           4.36e-05
# Time:                                    15:58:01   Log-Likelihood:                 550.44
# No. Observations:                             320   AIC:                            -1089.
# Df Residuals:                                 314   BIC:                            -1066.
# Df Model:                                       5
# Covariance Type:                        nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0476      0.016     -3.017      0.003      -0.079      -0.017
# leisure_by_emp        -0.0990      0.082     -1.209      0.228      -0.260       0.062
# occ_15                 0.6521      0.240      2.716      0.007       0.180       1.124
# total_pop          -1.427e-09   1.62e-09     -0.880      0.379   -4.62e-09    1.76e-09
# bachelors_graduate    -0.0017      0.000     -3.926      0.000      -0.002      -0.001
# white_nonhispanic      0.0004      0.000      2.479      0.014    7.41e-05       0.001
# ==============================================================================
# Omnibus:                       82.513   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1547.911
# Skew:                           0.476   Prob(JB):                         0.00
# Kurtosis:                      13.733   Cond. No.                     1.84e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.84e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Log transformed
columns = ['leisure_by_emp','occ_15','total_pop','bachelors_graduate', 'white_nonhispanic']
for col in columns:
    data["log-" + col] = np.log(1 + data[col])
x = data[['log-leisure_by_emp','log-occ_15','log-total_pop','log-bachelors_graduate', 'log-white_nonhispanic']].copy()
y = data['emp_tot_change_feb2020_jun2021']
model2 = sm.OLS(y,sm.add_constant(x),missing="drop").fit()
print(model2.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     emp_tot_change_feb2020_jun2021   R-squared:                       0.065
# Model:                                        OLS   Adj. R-squared:                  0.050
# Method:                             Least Squares   F-statistic:                     4.388
# Date:                            Wed, 11 Aug 2021   Prob (F-statistic):           0.000709
# Time:                                    15:58:01   Log-Likelihood:                 547.25
# No. Observations:                             320   AIC:                            -1083.
# Df Residuals:                                 314   BIC:                            -1060.
# Df Model:                                       5
# Covariance Type:                        nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.0195      0.056      0.346      0.729      -0.091       0.130
# log-leisure_by_emp        -0.1096      0.096     -1.145      0.253      -0.298       0.079
# log-occ_15                 0.5199      0.252      2.064      0.040       0.024       1.015
# log-total_pop             -0.0002      0.003     -0.060      0.952      -0.006       0.005
# log-bachelors_graduate    -0.0462      0.013     -3.555      0.000      -0.072      -0.021
# log-white_nonhispanic      0.0165      0.007      2.317      0.021       0.002       0.031
# ==============================================================================
# Omnibus:                       80.416   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1479.996
# Skew:                           0.447   Prob(JB):                         0.00
# Kurtosis:                      13.498   Cond. No.                     1.44e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Regression 2: Manufacturing

# %%
# No transformations
x = data[['leisure_by_emp','occ_15','total_pop','bachelors_graduate', 'white_nonhispanic']].copy()
y = data['manufacturing_change_feb2020_jun2021']
model3 = sm.OLS(y,sm.add_constant(x),missing='drop').fit()
print(model3.summary())
# Out:
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     manufacturing_change_feb2020_jun2021   R-squared:                       0.064
# Model:                                              OLS   Adj. R-squared:                  0.049
# Method:                                   Least Squares   F-statistic:                     4.263
# Date:                                  Wed, 11 Aug 2021   Prob (F-statistic):           0.000915
# Time:                                          15:58:01   Log-Likelihood:                 365.73
# No. Observations:                                   320   AIC:                            -719.5
# Df Residuals:                                       314   BIC:                            -696.9
# Df Model:                                             5
# Covariance Type:                              nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.1124      0.028     -3.998      0.000      -0.168      -0.057
# leisure_by_emp         0.3304      0.146      2.265      0.024       0.043       0.617
# occ_15                 1.0024      0.428      2.344      0.020       0.161       1.844
# total_pop          -4.524e-09   2.89e-09     -1.566      0.118   -1.02e-08    1.16e-09
# bachelors_graduate     0.0004      0.001      0.502      0.616      -0.001       0.002
# white_nonhispanic      0.0004      0.000      1.630      0.104   -8.71e-05       0.001
# ==============================================================================
# Omnibus:                       78.585   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              746.789
# Skew:                           0.688   Prob(JB):                    6.87e-163
# Kurtosis:                      10.356   Cond. No.                     1.84e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.84e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Log transformed
columns = ['leisure_by_emp','occ_15','total_pop','bachelors_graduate', 'white_nonhispanic']
for col in columns:
    data["log-" + col] = np.log(1 + data[col])
x = data[['log-leisure_by_emp','log-occ_15','log-total_pop','log-bachelors_graduate', 'log-white_nonhispanic']].copy()
y = data['manufacturing_change_feb2020_jun2021']
model4 = sm.OLS(y,sm.add_constant(x),missing="drop").fit()
print(model4.summary())
# Out:
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     manufacturing_change_feb2020_jun2021   R-squared:                       0.069
# Model:                                              OLS   Adj. R-squared:                  0.054
# Method:                                   Least Squares   F-statistic:                     4.677
# Date:                                  Wed, 11 Aug 2021   Prob (F-statistic):           0.000392
# Time:                                          15:58:01   Log-Likelihood:                 366.72
# No. Observations:                                   320   AIC:                            -721.4
# Df Residuals:                                       314   BIC:                            -698.8
# Df Model:                                             5
# Covariance Type:                              nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0527      0.099     -0.533      0.594      -0.247       0.142
# log-leisure_by_emp         0.3500      0.168      2.081      0.038       0.019       0.681
# log-occ_15                 1.1046      0.443      2.495      0.013       0.233       1.976
# log-total_pop             -0.0114      0.005     -2.318      0.021      -0.021      -0.002
# log-bachelors_graduate     0.0245      0.023      1.071      0.285      -0.020       0.069
# log-white_nonhispanic      0.0092      0.013      0.733      0.464      -0.015       0.034
# ==============================================================================
# Omnibus:                       68.916   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              662.780
# Skew:                           0.538   Prob(JB):                    1.20e-144
# Kurtosis:                       9.968   Cond. No.                     1.44e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Regression with added vars: population over 65 and divisions

# %%
# No transformations
data = pd.concat((data, pd.get_dummies(data['division'], drop_first=True)), axis=1)
x = data[['leisure_by_emp','occ_15','total_pop','bachelors_graduate','white_nonhispanic','above_65','East South Central Division', 
          'Middle Atlantic Division','Mountain Division', 'New England Division', 'Pacific Division','South Atlantic Division', 
          'West North Central Division','West South Central Division']].copy()
y = data['emp_tot_change_feb2020_jun2021']
model5 = sm.OLS(y,sm.add_constant(x),missing='drop').fit()
print(model5.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     emp_tot_change_feb2020_jun2021   R-squared:                       0.241
# Model:                                        OLS   Adj. R-squared:                  0.206
# Method:                             Least Squares   F-statistic:                     6.919
# Date:                            Wed, 11 Aug 2021   Prob (F-statistic):           2.41e-12
# Time:                                    15:58:01   Log-Likelihood:                 580.58
# No. Observations:                             320   AIC:                            -1131.
# Df Residuals:                                 305   BIC:                            -1075.
# Df Model:                                      14
# Covariance Type:                        nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -0.0788      0.019     -4.131      0.000      -0.116      -0.041
# leisure_by_emp                 -0.2078      0.083     -2.504      0.013      -0.371      -0.044
# occ_15                          0.5503      0.225      2.442      0.015       0.107       0.994
# total_pop                    5.951e-10   1.55e-09      0.384      0.701   -2.45e-09    3.64e-09
# bachelors_graduate             -0.0018      0.000     -4.317      0.000      -0.003      -0.001
# white_nonhispanic               0.0008      0.000      4.291      0.000       0.000       0.001
# above_65                       -0.0002      0.001     -0.335      0.738      -0.002       0.001
# East South Central Division     0.0287      0.009      3.055      0.002       0.010       0.047
# Middle Atlantic Division       -0.0138      0.009     -1.526      0.128      -0.032       0.004
# Mountain Division               0.0525      0.009      5.777      0.000       0.035       0.070
# New England Division           -0.0102      0.042     -0.244      0.807      -0.093       0.072
# Pacific Division                0.0324      0.009      3.665      0.000       0.015       0.050
# South Atlantic Division         0.0372      0.008      4.402      0.000       0.021       0.054
# West North Central Division     0.0220      0.010      2.160      0.032       0.002       0.042
# West South Central Division     0.0310      0.010      3.208      0.001       0.012       0.050
# ==============================================================================
# Omnibus:                      197.596   Durbin-Watson:                   2.152
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7414.159
# Skew:                           1.903   Prob(JB):                         0.00
# Kurtosis:                      26.272   Cond. No.                     1.87e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Log transformed
columns = ['leisure_by_emp','occ_15','total_pop','bachelors_graduate','white_nonhispanic','above_65']
for col in columns:
    data["log-" + col] = np.log(1 + data[col])
x = data[['log-leisure_by_emp','log-occ_15','log-total_pop','log-bachelors_graduate', 'log-white_nonhispanic', 
         'log-above_65','prepandemic_growth','East South Central Division', 'Middle Atlantic Division','Mountain Division', 'New England Division', 
          'Pacific Division','South Atlantic Division', 'West North Central Division','West South Central Division']].copy()
y = data['emp_tot_change_feb2020_jun2021']    # manufacturing_change_feb2020_jun2021 emp_tot_change_feb2020_jun2021
model6 = sm.OLS(y,sm.add_constant(x),missing="drop").fit()
print(model6.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     emp_tot_change_feb2020_jun2021   R-squared:                       0.232
# Model:                                        OLS   Adj. R-squared:                  0.194
# Method:                             Least Squares   F-statistic:                     6.111
# Date:                            Wed, 11 Aug 2021   Prob (F-statistic):           3.29e-11
# Time:                                    15:58:01   Log-Likelihood:                 578.62
# No. Observations:                             320   AIC:                            -1125.
# Df Residuals:                                 304   BIC:                            -1065.
# Df Model:                                      15
# Covariance Type:                        nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -0.0283      0.067     -0.423      0.673      -0.160       0.103
# log-leisure_by_emp             -0.2905      0.097     -2.988      0.003      -0.482      -0.099
# log-occ_15                      0.3854      0.238      1.622      0.106      -0.082       0.853
# log-total_pop                  -0.0005      0.003     -0.196      0.845      -0.006       0.005
# log-bachelors_graduate         -0.0497      0.013     -3.938      0.000      -0.075      -0.025
# log-white_nonhispanic           0.0268      0.008      3.301      0.001       0.011       0.043
# log-above_65                    0.0064      0.015      0.433      0.665      -0.023       0.035
# prepandemic_growth              0.1652      0.057      2.922      0.004       0.054       0.276
# East South Central Division     0.0220      0.010      2.311      0.022       0.003       0.041
# Middle Atlantic Division       -0.0148      0.009     -1.625      0.105      -0.033       0.003
# Mountain Division               0.0399      0.010      4.056      0.000       0.021       0.059
# New England Division           -0.0176      0.042     -0.421      0.674      -0.100       0.065
# Pacific Division                0.0161      0.009      1.757      0.080      -0.002       0.034
# South Atlantic Division         0.0244      0.009      2.835      0.005       0.007       0.041
# West North Central Division     0.0234      0.010      2.271      0.024       0.003       0.044
# West South Central Division     0.0229      0.010      2.380      0.018       0.004       0.042
# ==============================================================================
# Omnibus:                      189.796   Durbin-Watson:                   2.196
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7764.294
# Skew:                           1.756   Prob(JB):                         0.00
# Kurtosis:                      26.874   Cond. No.                     1.51e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Regression 4: Added variables for pandemic policies and health stats

# %%
change_dir('output//stage2')
output = pd.read_csv("final_output.csv")
output.columns
# Out:
# Index(['Unnamed: 0', 'area_code', 'hispanic', 'white_nonhispanic',
#        'black_nonhispanic', 'other_nonhispanic', 'asian_nonhispanic',
#        'above_65', 'prepandemic_growth', 'leisure_by_emp', 'total_emp_feb2020',
#        'manufacturing_emp_feb2020', 'service_emp_feb2020', 'total_emp_jun2021',
#        'manufacturing_emp_jun2021', 'service_emp_jun2021', 'total_employment',
#        'manufacturing', 'service', 'emp_tot_change_feb2020_jun2021',
#        'manufacturing_change_feb2020_jun2021',
#        'service_change_feb2020_jun2021', 'occ_15', 'total_pop', 'pop_excl',
#        'less_than_9grade', 'hs_nodiploma', 'ged', 'college_nodegree',
#        'associates', 'bachelors_graduate', 'CBSA Title', 'division', 'region',
#        'state', 'pop_by_metro', 'state_name', 'StringencyIndex',
#        'GovernmentResponseIndex', 'ContainmentHealthIndex',
#        'EconomicSupportIndex', 'deaths', 'deaths_by_pop'],
#       dtype='object')

# %%
# No transformations
output = pd.concat((output, pd.get_dummies(output['division'], drop_first=True)), axis=1)
x = output[['leisure_by_emp','occ_15','total_pop','bachelors_graduate','white_nonhispanic','black_nonhispanic','asian_nonhispanic',
          'hispanic','above_65','East South Central Division','Middle Atlantic Division','Mountain Division', 
          'New England Division', 'Pacific Division','South Atlantic Division','West North Central Division','West South Central Division',
          'StringencyIndex','GovernmentResponseIndex', 'ContainmentHealthIndex','EconomicSupportIndex','deaths_by_pop']].copy()
y = output['emp_tot_change_feb2020_jun2021']
model7 = sm.OLS(y,sm.add_constant(x),missing='drop').fit()
print(model7.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     emp_tot_change_feb2020_jun2021   R-squared:                       0.329
# Model:                                        OLS   Adj. R-squared:                  0.279
# Method:                             Least Squares   F-statistic:                     6.619
# Date:                            Wed, 11 Aug 2021   Prob (F-statistic):           6.59e-16
# Time:                                    15:58:01   Log-Likelihood:                 600.28
# No. Observations:                             320   AIC:                            -1155.
# Df Residuals:                                 297   BIC:                            -1068.
# Df Model:                                      22
# Covariance Type:                        nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           0.0166      0.111      0.149      0.882      -0.202       0.235
# leisure_by_emp                 -0.1430      0.084     -1.699      0.090      -0.309       0.023
# occ_15                          0.6781      0.223      3.040      0.003       0.239       1.117
# total_pop                    1.093e-09    1.5e-09      0.730      0.466   -1.85e-09    4.04e-09
# bachelors_graduate             -0.0014      0.000     -3.265      0.001      -0.002      -0.001
# white_nonhispanic               0.0009      0.001      0.882      0.379      -0.001       0.003
# black_nonhispanic               0.0002      0.001      0.232      0.817      -0.002       0.002
# asian_nonhispanic              -0.0018      0.001     -1.298      0.195      -0.005       0.001
# hispanic                        0.0005      0.001      0.504      0.615      -0.001       0.002
# above_65                    -7.664e-05      0.001     -0.102      0.919      -0.002       0.001
# East South Central Division     0.0227      0.011      2.069      0.039       0.001       0.044
# Middle Atlantic Division       -0.0109      0.011     -0.957      0.339      -0.033       0.012
# Mountain Division               0.0387      0.010      3.903      0.000       0.019       0.058
# New England Division            0.0030      0.040      0.075      0.940      -0.077       0.083
# Pacific Division                0.0395      0.012      3.331      0.001       0.016       0.063
# South Atlantic Division         0.0268      0.009      2.933      0.004       0.009       0.045
# West North Central Division     0.0017      0.011      0.153      0.878      -0.020       0.024
# West South Central Division     0.0183      0.010      1.813      0.071      -0.002       0.038
# StringencyIndex                -0.0013      0.001     -1.052      0.294      -0.004       0.001
# GovernmentResponseIndex         0.0131      0.013      1.036      0.301      -0.012       0.038
# ContainmentHealthIndex         -0.0126      0.011     -1.114      0.266      -0.035       0.010
# EconomicSupportIndex           -0.0014      0.002     -0.863      0.389      -0.005       0.002
# deaths_by_pop                  -1.3187      3.450     -0.382      0.703      -8.108       5.471
# ==============================================================================
# Omnibus:                      209.928   Durbin-Watson:                   2.215
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7292.771
# Skew:                           2.122   Prob(JB):                         0.00
# Kurtosis:                      25.999   Cond. No.                     2.98e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.98e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Log transformed
columns = ['leisure_by_emp','occ_15','total_pop','bachelors_graduate','white_nonhispanic','black_nonhispanic','asian_nonhispanic',
          'hispanic','above_65','StringencyIndex','GovernmentResponseIndex', 'ContainmentHealthIndex','EconomicSupportIndex','deaths_by_pop']
for col in columns:
    output["log-" + col] = np.log(1 + output[col])
x = output[['log-leisure_by_emp','log-occ_15','log-total_pop','log-bachelors_graduate', 'log-white_nonhispanic', 
         'log-above_65','prepandemic_growth','East South Central Division', 'Middle Atlantic Division','Mountain Division', 'New England Division', 
          'Pacific Division','South Atlantic Division', 'West North Central Division','West South Central Division',
          'log-StringencyIndex','log-GovernmentResponseIndex','log-ContainmentHealthIndex','log-EconomicSupportIndex','log-deaths_by_pop']].copy()
y = output['emp_tot_change_feb2020_jun2021']
# y = output['manufacturing_change_feb2020_jun2021']  
model8 = sm.OLS(y,sm.add_constant(x),missing="drop").fit()
print(model8.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     emp_tot_change_feb2020_jun2021   R-squared:                       0.279
# Model:                                        OLS   Adj. R-squared:                  0.231
# Method:                             Least Squares   F-statistic:                     5.789
# Date:                            Wed, 11 Aug 2021   Prob (F-statistic):           9.38e-13
# Time:                                    15:58:01   Log-Likelihood:                 588.82
# No. Observations:                             320   AIC:                            -1136.
# Df Residuals:                                 299   BIC:                            -1057.
# Df Model:                                      20
# Covariance Type:                        nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           0.6455      0.184      3.500      0.001       0.282       1.008
# log-leisure_by_emp             -0.2862      0.096     -2.993      0.003      -0.474      -0.098
# log-occ_15                      0.3462      0.235      1.470      0.143      -0.117       0.809
# log-total_pop                   0.0009      0.003      0.339      0.735      -0.004       0.006
# log-bachelors_graduate         -0.0448      0.013     -3.430      0.001      -0.070      -0.019
# log-white_nonhispanic           0.0219      0.009      2.490      0.013       0.005       0.039
# log-above_65                    0.0119      0.015      0.799      0.425      -0.017       0.041
# prepandemic_growth              0.0995      0.058      1.716      0.087      -0.015       0.214
# East South Central Division     0.0173      0.010      1.700      0.090      -0.003       0.037
# Middle Atlantic Division       -0.0062      0.012     -0.523      0.602      -0.030       0.017
# Mountain Division               0.0363      0.010      3.672      0.000       0.017       0.056
# New England Division           -0.0046      0.041     -0.113      0.910      -0.086       0.076
# Pacific Division                0.0260      0.012      2.181      0.030       0.003       0.050
# South Atlantic Division         0.0221      0.009      2.432      0.016       0.004       0.040
# West North Central Division     0.0002      0.011      0.021      0.983      -0.022       0.023
# West South Central Division     0.0143      0.010      1.418      0.157      -0.006       0.034
# log-StringencyIndex            -0.0299      0.072     -0.415      0.679      -0.172       0.112
# log-GovernmentResponseIndex     0.8220      0.647      1.271      0.205      -0.451       2.095
# log-ContainmentHealthIndex     -0.8726      0.600     -1.454      0.147      -2.053       0.308
# log-EconomicSupportIndex       -0.0916      0.083     -1.097      0.273      -0.256       0.073
# log-deaths_by_pop              -0.1263      3.625     -0.035      0.972      -7.260       7.007
# ==============================================================================
# Omnibus:                      203.453   Durbin-Watson:                   2.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8423.312
# Skew:                           1.959   Prob(JB):                         0.00
# Kurtosis:                      27.827   Cond. No.                     2.67e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.67e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Correlations

# %%
variables = ['hispanic', 'white_nonhispanic',
       'black_nonhispanic', 'other_nonhispanic', 'asian_nonhispanic',
       'above_65', 'prepandemic_growth', 'leisure_by_emp', 'total_emp_feb2020',
       'manufacturing_emp_feb2020', 'service_emp_feb2020', 'total_emp_jun2021',
       'manufacturing_emp_jun2021', 'service_emp_jun2021', 'total_employment',
       'manufacturing', 'service', 'emp_tot_change_feb2020_jun2021',
       'manufacturing_change_feb2020_jun2021',
       'service_change_feb2020_jun2021', 'occ_15', 'total_pop',
       'less_than_9grade', 'hs_nodiploma', 'ged', 'college_nodegree',
       'associates', 'bachelors_graduate']
data[variables].corr()
# Out:
#                                       hispanic  white_nonhispanic  \
# hispanic                              1.000000          -0.767776
# white_nonhispanic                    -0.767776           1.000000
# black_nonhispanic                    -0.259605          -0.319018
# other_nonhispanic                    -0.044461          -0.105850
# asian_nonhispanic                     0.110625          -0.351676
# above_65                             -0.214445           0.342070
# prepandemic_growth                    0.299847          -0.256355
# leisure_by_emp                        0.075919          -0.142451
# total_emp_feb2020                     0.127974          -0.260989
# manufacturing_emp_feb2020             0.126157          -0.253751
# service_emp_feb2020                   0.127417          -0.260283
# total_emp_jun2021                     0.130081          -0.264396
# manufacturing_emp_jun2021             0.125407          -0.252953
# service_emp_jun2021                   0.129906          -0.264292
# total_employment                      0.127331          -0.260033
# manufacturing                         0.125053          -0.251707
# service                               0.126849          -0.259497
# emp_tot_change_feb2020_jun2021        0.004943           0.120150
# manufacturing_change_feb2020_jun2021 -0.026371           0.110332
# service_change_feb2020_jun2021        0.043626           0.065406
# occ_15                               -0.079276          -0.037652
# total_pop                             0.166088          -0.282156
# less_than_9grade                      0.839957          -0.698706
# hs_nodiploma                          0.434803          -0.456452
# ged                                  -0.311682           0.350760
# college_nodegree                      0.084270          -0.042227
# associates                           -0.247393           0.339841
# bachelors_graduate                   -0.189461           0.078580
#
#                                       black_nonhispanic  other_nonhispanic  \
# hispanic                                      -0.259605          -0.044461
# white_nonhispanic                             -0.319018          -0.105850
# black_nonhispanic                              1.000000          -0.168078
# other_nonhispanic                             -0.168078           1.000000
# asian_nonhispanic                             -0.096969           0.290225
# above_65                                      -0.138016          -0.092720
# prepandemic_growth                            -0.065051          -0.117746
# leisure_by_emp                                -0.015361           0.264857
# total_emp_feb2020                              0.121188          -0.048624
# manufacturing_emp_feb2020                      0.105191          -0.057344
# service_emp_feb2020                            0.122392          -0.047271
# total_emp_jun2021                              0.124137          -0.050305
# manufacturing_emp_jun2021                      0.102819          -0.057237
# service_emp_jun2021                            0.126162          -0.049101
# total_employment                               0.120672          -0.048521
# manufacturing                                  0.103115          -0.056801
# service                                        0.122098          -0.047221
# emp_tot_change_feb2020_jun2021                -0.027794          -0.130732
# manufacturing_change_feb2020_jun2021          -0.179705           0.088357
# service_change_feb2020_jun2021                 0.015919          -0.138049
# occ_15                                         0.028668          -0.016646
# total_pop                                      0.095343          -0.050381
# less_than_9grade                              -0.110138          -0.103136
# hs_nodiploma                                   0.250354          -0.148151
# ged                                            0.081834          -0.121861
# college_nodegree                              -0.075295           0.281944
# associates                                    -0.203539           0.152445
# bachelors_graduate                            -0.009016           0.015350
#
#                                       asian_nonhispanic  above_65  \
# hispanic                                       0.110625 -0.214445
# white_nonhispanic                             -0.351676  0.342070
# black_nonhispanic                             -0.096969 -0.138016
# other_nonhispanic                              0.290225 -0.092720
# asian_nonhispanic                              1.000000 -0.180329
# above_65                                      -0.180329  1.000000
# prepandemic_growth                             0.170805  0.014718
# leisure_by_emp                                 0.149586  0.271457
# total_emp_feb2020                              0.305248 -0.147011
# manufacturing_emp_feb2020                      0.325977 -0.171578
# service_emp_feb2020                            0.300881 -0.143139
# total_emp_jun2021                              0.305179 -0.152700
# manufacturing_emp_jun2021                      0.331073 -0.173354
# service_emp_jun2021                            0.299975 -0.149095
# total_employment                               0.304946 -0.147168
# manufacturing                                  0.326480 -0.171603
# service                                        0.300493 -0.143311
# emp_tot_change_feb2020_jun2021                -0.310597  0.075458
# manufacturing_change_feb2020_jun2021           0.045882  0.077756
# service_change_feb2020_jun2021                -0.335892  0.047241
# occ_15                                         0.359137 -0.252684
# total_pop                                      0.314980 -0.142389
# less_than_9grade                               0.087768 -0.226544
# hs_nodiploma                                  -0.247389 -0.007533
# ged                                           -0.383263  0.344368
# college_nodegree                              -0.131667  0.034827
# associates                                    -0.057464  0.099417
# bachelors_graduate                             0.368241 -0.189870
#
#                                       prepandemic_growth  leisure_by_emp  \
# hispanic                                        0.299847        0.075919
# white_nonhispanic                              -0.256355       -0.142451
# black_nonhispanic                              -0.065051       -0.015361
# other_nonhispanic                              -0.117746        0.264857
# asian_nonhispanic                               0.170805        0.149586
# above_65                                        0.014718        0.271457
# prepandemic_growth                              1.000000        0.178521
# leisure_by_emp                                  0.178521        1.000000
# total_emp_feb2020                               0.160130       -0.056061
# manufacturing_emp_feb2020                       0.177219       -0.086559
# service_emp_feb2020                             0.157085       -0.052031
# total_emp_jun2021                               0.167697       -0.060928
# manufacturing_emp_jun2021                       0.185732       -0.086777
# service_emp_jun2021                             0.164343       -0.057208
# total_employment                                0.160200       -0.056121
# manufacturing                                   0.177386       -0.087420
# service                                         0.157145       -0.051970
# emp_tot_change_feb2020_jun2021                  0.198965       -0.133986
# manufacturing_change_feb2020_jun2021            0.174551        0.091372
# service_change_feb2020_jun2021                  0.185385       -0.140565
# occ_15                                          0.166018       -0.161680
# total_pop                                       0.184324       -0.035713
# less_than_9grade                                0.186836       -0.019355
# hs_nodiploma                                   -0.046949       -0.066812
# ged                                            -0.467627       -0.083861
# college_nodegree                                0.125066        0.138651
# associates                                     -0.077923       -0.036514
# bachelors_graduate                              0.236942        0.033125
#
#                                       total_emp_feb2020  \
# hispanic                                       0.127974
# white_nonhispanic                             -0.260989
# black_nonhispanic                              0.121188
# other_nonhispanic                             -0.048624
# asian_nonhispanic                              0.305248
# above_65                                      -0.147011
# prepandemic_growth                             0.160130
# leisure_by_emp                                -0.056061
# total_emp_feb2020                              1.000000
# manufacturing_emp_feb2020                      0.955248
# service_emp_feb2020                            0.999356
# total_emp_jun2021                              0.999166
# manufacturing_emp_jun2021                      0.951466
# service_emp_jun2021                            0.999354
# total_employment                               0.999981
# manufacturing                                  0.956479
# service                                        0.999320
# emp_tot_change_feb2020_jun2021                -0.116701
# manufacturing_change_feb2020_jun2021          -0.052454
# service_change_feb2020_jun2021                -0.112020
# occ_15                                         0.338661
# total_pop                                      0.970697
# less_than_9grade                               0.093606
# hs_nodiploma                                  -0.090717
# ged                                           -0.260718
# college_nodegree                              -0.227752
# associates                                    -0.194279
# bachelors_graduate                             0.306814
#
#                                       manufacturing_emp_feb2020  ...  \
# hispanic                                               0.126157  ...
# white_nonhispanic                                     -0.253751  ...
# black_nonhispanic                                      0.105191  ...
# other_nonhispanic                                     -0.057344  ...
# asian_nonhispanic                                      0.325977  ...
# above_65                                              -0.171578  ...
# prepandemic_growth                                     0.177219  ...
# leisure_by_emp                                        -0.086559  ...
# total_emp_feb2020                                      0.955248  ...
# manufacturing_emp_feb2020                              1.000000  ...
# service_emp_feb2020                                    0.944021  ...
# total_emp_jun2021                                      0.961498  ...
# manufacturing_emp_jun2021                              0.998841  ...
# service_emp_jun2021                                    0.950855  ...
# total_employment                                       0.955013  ...
# manufacturing                                          0.999891  ...
# service                                                0.943825  ...
# emp_tot_change_feb2020_jun2021                        -0.104610  ...
# manufacturing_change_feb2020_jun2021                  -0.083066  ...
# service_change_feb2020_jun2021                        -0.093475  ...
# occ_15                                                 0.359648  ...
# total_pop                                              0.962826  ...
# less_than_9grade                                       0.098300  ...
# hs_nodiploma                                          -0.088459  ...
# ged                                                   -0.265179  ...
# college_nodegree                                      -0.207791  ...
# associates                                            -0.192810  ...
# bachelors_graduate                                     0.299110  ...
#
#                                       manufacturing_change_feb2020_jun2021  \
# hispanic                                                         -0.026371
# white_nonhispanic                                                 0.110332
# black_nonhispanic                                                -0.179705
# other_nonhispanic                                                 0.088357
# asian_nonhispanic                                                 0.045882
# above_65                                                          0.077756
# prepandemic_growth                                                0.174551
# leisure_by_emp                                                    0.091372
# total_emp_feb2020                                                -0.052454
# manufacturing_emp_feb2020                                        -0.083066
# service_emp_feb2020                                              -0.048423
# total_emp_jun2021                                                -0.048180
# manufacturing_emp_jun2021                                        -0.063852
# service_emp_jun2021                                              -0.045852
# total_employment                                                 -0.051865
# manufacturing                                                    -0.079005
# service                                                          -0.048236
# emp_tot_change_feb2020_jun2021                                    0.397307
# manufacturing_change_feb2020_jun2021                              1.000000
# service_change_feb2020_jun2021                                    0.163973
# occ_15                                                            0.176395
# total_pop                                                        -0.051123
# less_than_9grade                                                 -0.095041
# hs_nodiploma                                                     -0.306693
# ged                                                              -0.230967
# college_nodegree                                                  0.157905
# associates                                                        0.212354
# bachelors_graduate                                                0.168255
#
#                                       service_change_feb2020_jun2021  \
# hispanic                                                    0.043626
# white_nonhispanic                                           0.065406
# black_nonhispanic                                           0.015919
# other_nonhispanic                                          -0.138049
# asian_nonhispanic                                          -0.335892
# above_65                                                    0.047241
# prepandemic_growth                                          0.185385
# leisure_by_emp                                             -0.140565
# total_emp_feb2020                                          -0.112020
# manufacturing_emp_feb2020                                  -0.093475
# service_emp_feb2020                                        -0.113589
# total_emp_jun2021                                          -0.101069
# manufacturing_emp_jun2021                                  -0.089516
# service_emp_jun2021                                        -0.101963
# total_employment                                           -0.111004
# manufacturing                                              -0.093896
# service                                                    -0.112432
# emp_tot_change_feb2020_jun2021                              0.956830
# manufacturing_change_feb2020_jun2021                        0.163973
# service_change_feb2020_jun2021                              1.000000
# occ_15                                                     -0.043250
# total_pop                                                  -0.100714
# less_than_9grade                                            0.064815
# hs_nodiploma                                                0.171320
# ged                                                         0.070032
# college_nodegree                                            0.293768
# associates                                                  0.029562
# bachelors_graduate                                         -0.245078
#
#                                         occ_15  total_pop  less_than_9grade  \
# hispanic                             -0.079276   0.166088          0.839957
# white_nonhispanic                    -0.037652  -0.282156         -0.698706
# black_nonhispanic                     0.028668   0.095343         -0.110138
# other_nonhispanic                    -0.016646  -0.050381         -0.103136
# asian_nonhispanic                     0.359137   0.314980          0.087768
# above_65                             -0.252684  -0.142389         -0.226544
# prepandemic_growth                    0.166018   0.184324          0.186836
# leisure_by_emp                       -0.161680  -0.035713         -0.019355
# total_emp_feb2020                     0.338661   0.970697          0.093606
# manufacturing_emp_feb2020             0.359648   0.962826          0.098300
# service_emp_feb2020                   0.334059   0.965758          0.092469
# total_emp_jun2021                     0.349262   0.971743          0.093741
# manufacturing_emp_jun2021             0.373675   0.960348          0.094459
# service_emp_jun2021                   0.343985   0.967376          0.093084
# total_employment                      0.339039   0.970443          0.093052
# manufacturing                         0.361532   0.963389          0.096600
# service                               0.334269   0.965507          0.092062
# emp_tot_change_feb2020_jun2021       -0.004606  -0.104965          0.025635
# manufacturing_change_feb2020_jun2021  0.176395  -0.051123         -0.095041
# service_change_feb2020_jun2021       -0.043250  -0.100714          0.064815
# occ_15                                1.000000   0.303812         -0.188188
# total_pop                             0.303812   1.000000          0.123106
# less_than_9grade                     -0.188188   0.123106          1.000000
# hs_nodiploma                         -0.437245  -0.071668          0.653082
# ged                                  -0.474842  -0.256123         -0.130065
# college_nodegree                     -0.274396  -0.195527         -0.073801
# associates                           -0.084649  -0.176394         -0.342926
# bachelors_graduate                    0.648040   0.270610         -0.348881
#
#                                       hs_nodiploma       ged  \
# hispanic                                  0.434803 -0.311682
# white_nonhispanic                        -0.456452  0.350760
# black_nonhispanic                         0.250354  0.081834
# other_nonhispanic                        -0.148151 -0.121861
# asian_nonhispanic                        -0.247389 -0.383263
# above_65                                 -0.007533  0.344368
# prepandemic_growth                       -0.046949 -0.467627
# leisure_by_emp                           -0.066812 -0.083861
# total_emp_feb2020                        -0.090717 -0.260718
# manufacturing_emp_feb2020                -0.088459 -0.265179
# service_emp_feb2020                      -0.090440 -0.258594
# total_emp_jun2021                        -0.093376 -0.267161
# manufacturing_emp_jun2021                -0.098840 -0.274480
# service_emp_jun2021                      -0.092103 -0.264601
# total_employment                         -0.091312 -0.260681
# manufacturing                            -0.091890 -0.266583
# service                                  -0.090698 -0.258411
# emp_tot_change_feb2020_jun2021            0.068877  0.027390
# manufacturing_change_feb2020_jun2021     -0.306693 -0.230967
# service_change_feb2020_jun2021            0.171320  0.070032
# occ_15                                   -0.437245 -0.474842
# total_pop                                -0.071668 -0.256123
# less_than_9grade                          0.653082 -0.130065
# hs_nodiploma                              1.000000  0.405748
# ged                                       0.405748  1.000000
# college_nodegree                          0.047377 -0.107537
# associates                               -0.378942 -0.009593
# bachelors_graduate                       -0.729712 -0.713250
#
#                                       college_nodegree  associates  \
# hispanic                                      0.084270   -0.247393
# white_nonhispanic                            -0.042227    0.339841
# black_nonhispanic                            -0.075295   -0.203539
# other_nonhispanic                             0.281944    0.152445
# asian_nonhispanic                            -0.131667   -0.057464
# above_65                                      0.034827    0.099417
# prepandemic_growth                            0.125066   -0.077923
# leisure_by_emp                                0.138651   -0.036514
# total_emp_feb2020                            -0.227752   -0.194279
# manufacturing_emp_feb2020                    -0.207791   -0.192810
# service_emp_feb2020                          -0.228790   -0.193277
# total_emp_jun2021                            -0.226868   -0.198421
# manufacturing_emp_jun2021                    -0.208651   -0.190027
# service_emp_jun2021                          -0.227871   -0.198318
# total_employment                             -0.227611   -0.194078
# manufacturing                                -0.208336   -0.190753
# service                                      -0.228608   -0.193323
# emp_tot_change_feb2020_jun2021                0.286364    0.094692
# manufacturing_change_feb2020_jun2021          0.157905    0.212354
# service_change_feb2020_jun2021                0.293768    0.029562
# occ_15                                       -0.274396   -0.084649
# total_pop                                    -0.195527   -0.176394
# less_than_9grade                             -0.073801   -0.342926
# hs_nodiploma                                  0.047377   -0.378942
# ged                                          -0.107537   -0.009593
# college_nodegree                              1.000000    0.293786
# associates                                    0.293786    1.000000
# bachelors_graduate                           -0.381417   -0.101703
#
#                                       bachelors_graduate
# hispanic                                       -0.189461
# white_nonhispanic                               0.078580
# black_nonhispanic                              -0.009016
# other_nonhispanic                               0.015350
# asian_nonhispanic                               0.368241
# above_65                                       -0.189870
# prepandemic_growth                              0.236942
# leisure_by_emp                                  0.033125
# total_emp_feb2020                               0.306814
# manufacturing_emp_feb2020                       0.299110
# service_emp_feb2020                             0.305886
# total_emp_jun2021                               0.312512
# manufacturing_emp_jun2021                       0.309556
# service_emp_jun2021                             0.311015
# total_employment                                0.307052
# manufacturing                                   0.301416
# service                                         0.305913
# emp_tot_change_feb2020_jun2021                 -0.184515
# manufacturing_change_feb2020_jun2021            0.168255
# service_change_feb2020_jun2021                 -0.245078
# occ_15                                          0.648040
# total_pop                                       0.270610
# less_than_9grade                               -0.348881
# hs_nodiploma                                   -0.729712
# ged                                            -0.713250
# college_nodegree                               -0.381417
# associates                                     -0.101703
# bachelors_graduate                              1.000000
#
# [28 rows x 28 columns]

# %%
variables = ['white_nonhispanic','above_65', 'leisure_by_emp',  'occ_15', 'total_pop','bachelors_graduate','prepandemic_growth','manufacturing_change_feb2020_jun2021', 'emp_tot_change_feb2020_jun2021']
data[variables].corr()
# Out:
#                                       white_nonhispanic  above_65  \
# white_nonhispanic                              1.000000  0.342070
# above_65                                       0.342070  1.000000
# leisure_by_emp                                -0.142451  0.271457
# occ_15                                        -0.037652 -0.252684
# total_pop                                     -0.282156 -0.142389
# bachelors_graduate                             0.078580 -0.189870
# prepandemic_growth                            -0.256355  0.014718
# manufacturing_change_feb2020_jun2021           0.110332  0.077756
# emp_tot_change_feb2020_jun2021                 0.120150  0.075458
#
#                                       leisure_by_emp    occ_15  total_pop  \
# white_nonhispanic                          -0.142451 -0.037652  -0.282156
# above_65                                    0.271457 -0.252684  -0.142389
# leisure_by_emp                              1.000000 -0.161680  -0.035713
# occ_15                                     -0.161680  1.000000   0.303812
# total_pop                                  -0.035713  0.303812   1.000000
# bachelors_graduate                          0.033125  0.648040   0.270610
# prepandemic_growth                          0.178521  0.166018   0.184324
# manufacturing_change_feb2020_jun2021        0.091372  0.176395  -0.051123
# emp_tot_change_feb2020_jun2021             -0.133986 -0.004606  -0.104965
#
#                                       bachelors_graduate  prepandemic_growth  \
# white_nonhispanic                               0.078580           -0.256355
# above_65                                       -0.189870            0.014718
# leisure_by_emp                                  0.033125            0.178521
# occ_15                                          0.648040            0.166018
# total_pop                                       0.270610            0.184324
# bachelors_graduate                              1.000000            0.236942
# prepandemic_growth                              0.236942            1.000000
# manufacturing_change_feb2020_jun2021            0.168255            0.174551
# emp_tot_change_feb2020_jun2021                 -0.184515            0.198965
#
#                                       manufacturing_change_feb2020_jun2021  \
# white_nonhispanic                                                 0.110332
# above_65                                                          0.077756
# leisure_by_emp                                                    0.091372
# occ_15                                                            0.176395
# total_pop                                                        -0.051123
# bachelors_graduate                                                0.168255
# prepandemic_growth                                                0.174551
# manufacturing_change_feb2020_jun2021                              1.000000
# emp_tot_change_feb2020_jun2021                                    0.397307
#
#                                       emp_tot_change_feb2020_jun2021
# white_nonhispanic                                           0.120150
# above_65                                                    0.075458
# leisure_by_emp                                             -0.133986
# occ_15                                                     -0.004606
# total_pop                                                  -0.104965
# bachelors_graduate                                         -0.184515
# prepandemic_growth                                          0.198965
# manufacturing_change_feb2020_jun2021                        0.397307
# emp_tot_change_feb2020_jun2021                              1.000000
