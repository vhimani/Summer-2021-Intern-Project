# %% [markdown]
# # Stage 3 Analysis

# %% [markdown]
# The stage 3 part of the analysis includes pandemic specific variables - variables for pandemic policies, and other health statistics related with Covid-19 (deaths and vaccination rates). Personal median income is also included as an economic indicator.

# %%
# Import libraries
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import os
from os import *
import sys
sys.path.append("../")
import urllib.request
import requests
import json

# %%
# Change directory
def change_dir(newpath):
    get_path = sys.path[0].split("\\")      
    del get_path[-1]                                                  
    get_path.append(newpath)                    
    path = "\\".join(get_path)              
    os.chdir(path)

# %%
# Retrieve the stage 2 merged files
change_dir('output//stage2')
stage2_file = pd.read_csv('output.csv')
stage2_file = stage2_file.drop(columns=['Unnamed: 0'])
stage2_file
# Out:
#      area_code  hispanic  white_nonhispanic  black_nonhispanic  \
# 0      10180.0     24.12              63.99               7.49
# 1      10420.0      2.22              79.34              12.49
# 2      10500.0      3.12              41.22              55.03
# 3      10540.0      9.52              84.34               0.60
# 4      10580.0      5.42              79.32               8.20
# ..         ...       ...                ...                ...
# 364    49620.0      8.08              82.62               5.79
# 365    49660.0      4.47              83.14               9.36
# 366    49700.0     30.65              48.98               2.82
# 367    49740.0     64.61              30.15               1.86
# 368    71650.0     11.59              70.11               6.78
#
#      other_nonhispanic  asian_nonhispanic   above_65  prepandemic_growth  \
# 0                 2.46               1.94  15.271998            0.061584
# 1                 2.48               3.47  18.158182            0.008289
# 2                 1.45               1.25  16.949280            0.027823
# 3                 4.20               1.34  19.069126            0.106132
# 4                 2.53               4.53  17.980738            0.033501
# ..                 ...                ...        ...                 ...
# 364               2.02               1.49  17.954696            0.040929
# 365               2.02               1.01  21.324866           -0.040301
# 366               5.18              12.37  14.441553            0.132029
# 367               2.10               1.28  19.319229            0.086792
# 368               2.08               9.45  15.958125            0.063666
#
#      leisure_by_emp  total_emp_feb2020  ...  hs_nodiploma    ged  \
# 0          0.111297               71.2  ...          7.73  32.28
# 1          0.096521              336.5  ...          5.90  31.68
# 2               NaN               62.2  ...         11.13  31.97
# 3          0.079524               46.6  ...          7.60  29.00
# 4          0.082655              466.1  ...          5.29  26.17
# ..              ...                ...  ...           ...    ...
# 364        0.084918              185.4  ...          7.00  39.60
# 365        0.109646              215.3  ...          6.53  37.65
# 366        0.098186               44.6  ...         10.09  23.43
# 367        0.106338               59.1  ...         13.20  25.70
# 368        0.093706             2767.7  ...          4.41  22.10
#
#      college_nodegree  associates  bachelors_graduate  \
# 0               24.66        7.70               23.28
# 1               20.30        8.27               31.69
# 2               22.81        9.55               20.19
# 3               31.20       10.00               19.30
# 4               16.21       12.37               37.53
# ..                ...         ...                 ...
# 364             16.30        9.20               24.90
# 365             21.11        8.45               23.66
# 366             28.08       10.80               17.71
# 367             24.80        7.70               15.00
# 368             14.15        6.86               48.22
#
#                             CBSA Title                     division  \
# 0                          Abilene, TX  West South Central Division
# 1                            Akron, OH  East North Central Division
# 2                           Albany, GA      South Atlantic Division
# 3                           Albany, OR             Pacific Division
# 4          Albany-Schenectady-Troy, NY     Middle Atlantic Division
# ..                                 ...                          ...
# 364                   York-Hanover, PA     Middle Atlantic Division
# 365  Youngstown-Warren-Boardman, OH-PA  East North Central Division
# 366                      Yuba City, CA             Pacific Division
# 367                           Yuma, AZ            Mountain Division
# 368     Boston-Cambridge-Nashua, MA-NH         New England Division
#
#                region  state  pop_by_metro
# 0        South Region     48      172060.0
# 1      Midwest Region     39      703479.0
# 2        South Region     13      146726.0
# 3         West Region     41      129749.0
# 4    Northeast Region     36      880381.0
# ..                ...    ...           ...
# 364  Northeast Region     42      449058.0
# 365    Midwest Region     39      536081.0
# 366       West Region      6      175639.0
# 367       West Region      4      213787.0
# 368  Northeast Region     25           NaN
#
# [369 rows x 35 columns]

# %% [markdown]
# ## Pandemic Policies

# %% [markdown]
# The averages of four indices: stringency, government response, containment health, and economic support are computed from March 2020 to June 2021 at the state level.

# %%
# Clean up pandemic policies file
change_dir('output')
pandemic_policies = pd.read_csv("pandemic_policies.csv")
pandemic_policies["year_month"] = pandemic_policies['year'].astype(str) + str('-') + pandemic_policies['month'].astype(str)
months_to_exclude = ['2020-1','2020-2','2021-7','2021-8']
pandemic_policies = pandemic_policies[~pandemic_policies['year_month'].isin(months_to_exclude)]
pandemic_policies = pandemic_policies.groupby('state').mean().reset_index()
pandemic_policies = pandemic_policies.drop(columns=['year','month','Unnamed: 0'])
pandemic_policies = pandemic_policies.rename(columns=({'state':'state_name','fips':'state'}))
pandemic_policies
# Out:
#               state_name  StringencyIndex  GovernmentResponseIndex  \
# 0                Alabama        46.763696                51.103417
# 1                 Alaska        56.752059                57.579288
# 2                Arizona        52.612700                54.854439
# 3               Arkansas        54.760006                57.273130
# 4             California        63.051351                67.141762
# 5               Colorado        57.806356                58.671330
# 6            Connecticut        62.514697                66.263142
# 7               Delaware        60.338009                62.078700
# 8   District of Columbia        66.044084                64.805929
# 9                Florida        52.481696                54.340970
# 10               Georgia        55.921999                56.254949
# 11                Hawaii        72.382913                67.845066
# 12                 Idaho        54.293494                49.706118
# 13              Illinois        58.311683                57.265306
# 14               Indiana        51.468152                53.272674
# 15                  Iowa        46.978848                51.330011
# 16                Kansas        53.353460                53.608999
# 17              Kentucky        59.647707                57.011609
# 18             Louisiana        60.548802                57.663748
# 19                 Maine        65.325592                60.287129
# 20              Maryland        60.603047                62.575210
# 21         Massachusetts        62.509786                62.408832
# 22              Michigan        61.249214                61.198052
# 23             Minnesota        58.316353                54.550265
# 24           Mississippi        52.465433                50.602601
# 25              Missouri        49.554441                52.023475
# 26               Montana        54.004399                56.192869
# 27              Nebraska        51.354933                56.174577
# 28                Nevada        55.690562                54.261914
# 29         New Hampshire        51.007877                53.184086
# 30            New Jersey        57.649472                62.189352
# 31            New Mexico        70.252954                66.432469
# 32              New York        66.881749                71.821582
# 33        North Carolina        61.017815                59.635278
# 34          North Dakota        43.646120                47.192799
# 35                  Ohio        58.787620                59.645174
# 36              Oklahoma        47.492940                49.223901
# 37                Oregon        60.793028                59.832710
# 38          Pennsylvania        55.666169                59.711847
# 39          Rhode Island        64.726317                68.190213
# 40        South Carolina        51.619808                55.805248
# 41          South Dakota        43.765671                44.815035
# 42             Tennessee        55.202891                53.805655
# 43                 Texas        53.639829                52.692697
# 44                  Utah        47.529766                46.997790
# 45               Vermont        64.410651                66.804574
# 46              Virginia        56.810436                56.528682
# 47            Washington        61.779688                61.220410
# 48         West Virginia        53.952980                55.959923
# 49             Wisconsin        54.465239                54.801377
# 50               Wyoming        58.631636                55.919783
#
#     ContainmentHealthIndex  EconomicSupportIndex  state
# 0                52.595120             41.381048    1.0
# 1                57.956765             54.937836    2.0
# 2                55.531136             50.730847    4.0
# 3                59.352424             42.704133    5.0
# 4                64.823398             80.771169    6.0
# 5                57.803300             64.742944    8.0
# 6                65.050539             74.746304    9.0
# 7                61.929548             63.130040   10.0
# 8                64.572282             66.439852   11.0
# 9                54.719222             51.695228   12.0
# 10               55.945863             58.414579   13.0
# 11               69.473220             56.451613   15.0
# 12               51.147333             40.225674   16.0
# 13               56.787777             60.616599   17.0
# 14               53.590257             51.058468   18.0
# 15               49.094110             66.985887   19.0
# 16               54.656331             46.278562   20.0
# 17               60.449469             45.254536   21.0
# 18               59.388421             45.588038   22.0
# 19               61.425673             52.312668   23.0
# 20               61.693223             68.755040   24.0
# 21               65.276183             42.347950   25.0
# 22               63.852321             42.615927   26.0
# 23               56.275692             42.464718   27.0
# 24               51.263303             45.990423   28.0
# 25               52.230649             50.590558   29.0
# 26               57.820048             44.791667   30.0
# 27               54.710776             66.418011   31.0
# 28               55.402704             46.263861   32.0
# 29               54.177365             46.233199   33.0
# 30               60.998058             70.521673   34.0
# 31               69.535366             44.707661   35.0
# 32               68.375444             95.937500   36.0
# 33               59.729226             58.971774   37.0
# 34               48.224059             39.978159   38.0
# 35               62.129232             42.263105   39.0
# 36               50.549580             39.927755   40.0
# 37               58.962529             66.683468   41.0
# 38               59.995945             57.721774   42.0
# 39               66.869937             77.429435   44.0
# 40               57.143145             46.446573   45.0
# 41               45.502007             39.997480   46.0
# 42               55.536908             41.767473   47.0
# 43               54.371357             40.948421   48.0
# 44               48.031972             39.751344   49.0
# 45               65.289606             77.419355   50.0
# 46               56.119212             59.400202   51.0
# 47               60.194635             68.397177   53.0
# 48               57.620293             44.618616   54.0
# 49               56.031155             46.194556   55.0
# 50               57.278005             46.404570   56.0

# %%
# Merge the pandemic policies variables with the rest of the database
merged = stage2_file.merge(pandemic_policies, on=['state'], how='left')
merged
# Out:
#      area_code  hispanic  white_nonhispanic  black_nonhispanic  \
# 0      10180.0     24.12              63.99               7.49
# 1      10420.0      2.22              79.34              12.49
# 2      10500.0      3.12              41.22              55.03
# 3      10540.0      9.52              84.34               0.60
# 4      10580.0      5.42              79.32               8.20
# ..         ...       ...                ...                ...
# 364    49620.0      8.08              82.62               5.79
# 365    49660.0      4.47              83.14               9.36
# 366    49700.0     30.65              48.98               2.82
# 367    49740.0     64.61              30.15               1.86
# 368    71650.0     11.59              70.11               6.78
#
#      other_nonhispanic  asian_nonhispanic   above_65  prepandemic_growth  \
# 0                 2.46               1.94  15.271998            0.061584
# 1                 2.48               3.47  18.158182            0.008289
# 2                 1.45               1.25  16.949280            0.027823
# 3                 4.20               1.34  19.069126            0.106132
# 4                 2.53               4.53  17.980738            0.033501
# ..                 ...                ...        ...                 ...
# 364               2.02               1.49  17.954696            0.040929
# 365               2.02               1.01  21.324866           -0.040301
# 366               5.18              12.37  14.441553            0.132029
# 367               2.10               1.28  19.319229            0.086792
# 368               2.08               9.45  15.958125            0.063666
#
#      leisure_by_emp  total_emp_feb2020  ...  \
# 0          0.111297               71.2  ...
# 1          0.096521              336.5  ...
# 2               NaN               62.2  ...
# 3          0.079524               46.6  ...
# 4          0.082655              466.1  ...
# ..              ...                ...  ...
# 364        0.084918              185.4  ...
# 365        0.109646              215.3  ...
# 366        0.098186               44.6  ...
# 367        0.106338               59.1  ...
# 368        0.093706             2767.7  ...
#
#                             CBSA Title                     division  \
# 0                          Abilene, TX  West South Central Division
# 1                            Akron, OH  East North Central Division
# 2                           Albany, GA      South Atlantic Division
# 3                           Albany, OR             Pacific Division
# 4          Albany-Schenectady-Troy, NY     Middle Atlantic Division
# ..                                 ...                          ...
# 364                   York-Hanover, PA     Middle Atlantic Division
# 365  Youngstown-Warren-Boardman, OH-PA  East North Central Division
# 366                      Yuba City, CA             Pacific Division
# 367                           Yuma, AZ            Mountain Division
# 368     Boston-Cambridge-Nashua, MA-NH         New England Division
#
#                region  state  pop_by_metro     state_name  StringencyIndex  \
# 0        South Region     48      172060.0          Texas        53.639829
# 1      Midwest Region     39      703479.0           Ohio        58.787620
# 2        South Region     13      146726.0        Georgia        55.921999
# 3         West Region     41      129749.0         Oregon        60.793028
# 4    Northeast Region     36      880381.0       New York        66.881749
# ..                ...    ...           ...            ...              ...
# 364  Northeast Region     42      449058.0   Pennsylvania        55.666169
# 365    Midwest Region     39      536081.0           Ohio        58.787620
# 366       West Region      6      175639.0     California        63.051351
# 367       West Region      4      213787.0        Arizona        52.612700
# 368  Northeast Region     25           NaN  Massachusetts        62.509786
#
#      GovernmentResponseIndex  ContainmentHealthIndex  EconomicSupportIndex
# 0                  52.692697               54.371357             40.948421
# 1                  59.645174               62.129232             42.263105
# 2                  56.254949               55.945863             58.414579
# 3                  59.832710               58.962529             66.683468
# 4                  71.821582               68.375444             95.937500
# ..                       ...                     ...                   ...
# 364                59.711847               59.995945             57.721774
# 365                59.645174               62.129232             42.263105
# 366                67.141762               64.823398             80.771169
# 367                54.854439               55.531136             50.730847
# 368                62.408832               65.276183             42.347950
#
# [369 rows x 40 columns]

# %% [markdown]
# ## Death rates

# %% [markdown]
# Covid death rates are reported on a county level. The cumulative totals as at June 30th, 2021 are used.

# %%
# Retrieve and clean-up covid deaths by county database
change_dir('output')
death_by_county = pd.read_csv('health_stats_county.csv')
death_by_county.drop(death_by_county.columns.difference(['FIPS', 'Admin2', 'Province_State', '6/30/2021']), 1, inplace=True)
death_by_county = death_by_county[death_by_county['Admin2'] != 'Unassigned']
death_by_county = death_by_county[death_by_county['FIPS'].notna()]
death_by_county = death_by_county.rename(columns={'FIPS':'fips','Admin2':'Name','Province_State':'state_proper','6/30/2021':'deaths'})
death_by_county['fips'].nunique()
states_exclude = ['American Samoa','Diamond Princess','Grand Princess','Puerto Rico','Northern Mariana Islands','Guam','Virgin Islands']
death_by_county = death_by_county[~death_by_county['state_proper'].isin(states_exclude)]
death_by_county
# Out:
# 0        1001.0
# 1        1003.0
# 2        1005.0
# 3        1007.0
# 4        1009.0
#          ...
# 3285    56037.0
# 3286    56039.0
# 3287    56041.0
# 3288    56043.0
# 3289    56045.0
# Name: fips, Length: 3195, dtype: float64

# %%
# Add state abbreviations to the covid deaths dataset
change_dir('output//stage2')
delineation_files = pd.read_csv('delineation_files.csv')
death_by_county = pd.merge(death_by_county,delineation_files[['state_proper','state_abbr']], on='state_proper', how='left').drop_duplicates()
death_by_county = death_by_county.rename(columns={'state_abbr':'State'})
death_by_county
# Out:
#            fips        Name state_proper  deaths State
# 0        1001.0     Autauga      Alabama     113    AL
# 43       1003.0     Baldwin      Alabama     315    AL
# 86       1005.0     Barbour      Alabama      60    AL
# 129      1007.0        Bibb      Alabama      64    AL
# 172      1009.0      Blount      Alabama     139    AL
# ...         ...         ...          ...     ...   ...
# 173019  56037.0  Sweetwater      Wyoming      40    WY
# 173028  56039.0       Teton      Wyoming      11    WY
# 173037  56041.0       Uinta      Wyoming      13    WY
# 173046  56043.0    Washakie      Wyoming      26    WY
# 173055  56045.0      Weston      Wyoming       6    WY
#
# [3195 rows x 5 columns]

# %%
# Get county and states codes
change_dir('input')
fips1 = pd.read_csv('US_FIPS_Codes.csv')
fips2 = pd.read_csv('fips_state_county.csv')
fips2 = fips2.merge(fips1,on=['Name','State'],how='left')
fips2 = fips2.rename(columns={'FIPS State':'fips_state','FIPS County':'county'})
fips2 = pd.merge(fips2, delineation_files[['fips_state','county','area_code','CBSA Title']], on=['fips_state','county'], how='left')
fips2.drop(fips2.columns.difference(['FIPS', 'Name', 'State', 'fips_state','county','area_code','CBSA Title']), 1, inplace=True)
fips2
# Out:
#        FIPS        Name State  fips_state  county  area_code  \
# 0      1001     Autauga    AL         1.0     1.0    33860.0
# 1      1003     Baldwin    AL         1.0     3.0    19300.0
# 2      1005     Barbour    AL         1.0     5.0    21640.0
# 3      1007        Bibb    AL         1.0     7.0    13820.0
# 4      1009      Blount    AL         1.0     9.0    13820.0
# ...     ...         ...   ...         ...     ...        ...
# 3137  56037  Sweetwater    WY        56.0    37.0    40540.0
# 3138  56039       Teton    WY        56.0    39.0    27220.0
# 3139  56041       Uinta    WY        56.0    41.0    21740.0
# 3140  56043    Washakie    WY        56.0    43.0        NaN
# 3141  56045      Weston    WY        56.0    45.0        NaN
#
#                      CBSA Title
# 0                Montgomery, AL
# 1     Daphne-Fairhope-Foley, AL
# 2                Eufaula, AL-GA
# 3         Birmingham-Hoover, AL
# 4         Birmingham-Hoover, AL
# ...                         ...
# 3137           Rock Springs, WY
# 3138             Jackson, WY-ID
# 3139               Evanston, WY
# 3140                        NaN
# 3141                        NaN
#
# [3142 rows x 7 columns]

# %%
# Merge the deaths dataset with the area codes
death_by_county = fips2.merge(death_by_county, on=['Name','State'], how='left')
death_by_county = death_by_county.groupby('area_code').sum().reset_index()
death_by_county
# Out:
#      area_code    FIPS  fips_state  county      fips   deaths
# 0      10100.0   92058        92.0    58.0   92058.0    109.0
# 1      10140.0   53027        53.0    27.0   53027.0     76.0
# 2      10180.0  144753       144.0   753.0  144753.0    511.0
# 3      10220.0   40123        40.0   123.0   40123.0     80.0
# 4      10300.0   26091        26.0    91.0   26091.0    170.0
# ..         ...     ...         ...     ...       ...      ...
# 926    49700.0   12216        12.0   216.0   12216.0    165.0
# 927    49740.0    4027         4.0    27.0    4027.0    848.0
# 928    49780.0   39119        39.0   119.0   39119.0    137.0
# 929    49820.0   48505        48.0   505.0   48505.0     36.0
# 930    71650.0  249147       249.0   147.0  249147.0  14836.0
#
# [931 rows x 6 columns]

# %%
merged2 = pd.merge(merged, death_by_county[['area_code','deaths']],on='area_code',how='left')
merged2['deaths_by_pop'] = merged2['deaths']/merged2['total_pop']
merged2
# Out:
#      area_code  hispanic  white_nonhispanic  black_nonhispanic  \
# 0      10180.0     24.12              63.99               7.49
# 1      10420.0      2.22              79.34              12.49
# 2      10500.0      3.12              41.22              55.03
# 3      10540.0      9.52              84.34               0.60
# 4      10580.0      5.42              79.32               8.20
# ..         ...       ...                ...                ...
# 364    49620.0      8.08              82.62               5.79
# 365    49660.0      4.47              83.14               9.36
# 366    49700.0     30.65              48.98               2.82
# 367    49740.0     64.61              30.15               1.86
# 368    71650.0     11.59              70.11               6.78
#
#      other_nonhispanic  asian_nonhispanic   above_65  prepandemic_growth  \
# 0                 2.46               1.94  15.271998            0.061584
# 1                 2.48               3.47  18.158182            0.008289
# 2                 1.45               1.25  16.949280            0.027823
# 3                 4.20               1.34  19.069126            0.106132
# 4                 2.53               4.53  17.980738            0.033501
# ..                 ...                ...        ...                 ...
# 364               2.02               1.49  17.954696            0.040929
# 365               2.02               1.01  21.324866           -0.040301
# 366               5.18              12.37  14.441553            0.132029
# 367               2.10               1.28  19.319229            0.086792
# 368               2.08               9.45  15.958125            0.063666
#
#      leisure_by_emp  total_emp_feb2020  ...            region  state  \
# 0          0.111297               71.2  ...      South Region     48
# 1          0.096521              336.5  ...    Midwest Region     39
# 2               NaN               62.2  ...      South Region     13
# 3          0.079524               46.6  ...       West Region     41
# 4          0.082655              466.1  ...  Northeast Region     36
# ..              ...                ...  ...               ...    ...
# 364        0.084918              185.4  ...  Northeast Region     42
# 365        0.109646              215.3  ...    Midwest Region     39
# 366        0.098186               44.6  ...       West Region      6
# 367        0.106338               59.1  ...       West Region      4
# 368        0.093706             2767.7  ...  Northeast Region     25
#
#      pop_by_metro     state_name  StringencyIndex  GovernmentResponseIndex  \
# 0        172060.0          Texas        53.639829                52.692697
# 1        703479.0           Ohio        58.787620                59.645174
# 2        146726.0        Georgia        55.921999                56.254949
# 3        129749.0         Oregon        60.793028                59.832710
# 4        880381.0       New York        66.881749                71.821582
# ..            ...            ...              ...                      ...
# 364      449058.0   Pennsylvania        55.666169                59.711847
# 365      536081.0           Ohio        58.787620                59.645174
# 366      175639.0     California        63.051351                67.141762
# 367      213787.0        Arizona        52.612700                54.854439
# 368           NaN  Massachusetts        62.509786                62.408832
#
#      ContainmentHealthIndex  EconomicSupportIndex   deaths  deaths_by_pop
# 0                 54.371357             40.948421    511.0       0.002970
# 1                 62.129232             42.263105   1231.0       0.001750
# 2                 55.945863             58.414579    499.0       0.003401
# 3                 58.962529             66.683468     81.0       0.000624
# 4                 68.375444             95.937500    892.0       0.001013
# ..                      ...                   ...      ...            ...
# 364               59.995945             57.721774    826.0       0.001839
# 365               62.129232             42.263105   1367.0       0.002081
# 366               64.823398             80.771169    165.0       0.000939
# 367               55.531136             50.730847    848.0       0.003967
# 368               65.276183             42.347950  14836.0       0.002075
#
# [369 rows x 42 columns]

# %% [markdown]
# ## Vaccines

# %% [markdown]
# Vaccination counts are sourced at the county level. Cumulative totals as at June 30th, 2021 are used for analysis.

# %%
# Retrieve and clean up vaccination data 
change_dir('output')
vaccs = pd.read_csv('vaccines.csv')
vaccs = vaccs.drop(columns=['2020-12-31','2021-01-31','2021-02-28','2021-03-31','2021-04-30','2021-05-31','2021-07-31'])
states_exclude = ['GU', 'PR', 'VI', 'AS','FM', 'MH', 'MP', 'PW', 'UNK']
vaccs = vaccs[~vaccs['Recip_State'].isin(states_exclude)]
vaccs = vaccs[vaccs['FIPS'] != "UNK"]
vaccs['state'] = vaccs['FIPS'].astype(str).str[:2]
vaccs['county'] = vaccs['FIPS'].astype(str).str[2:]
vaccs = vaccs.fillna(0)
vaccs[['FIPS','2021-06-30','state','county']] = vaccs[['FIPS','2021-06-30','state','county']].astype(int)
vaccs =  vaccs.rename(columns={'2021-06-30':'vaccines'})

# %%
# Merge area codes 
vaccs = delineation_files.merge(vaccs).drop_duplicates()
vaccs = vaccs.groupby('area_code').sum().reset_index()
vaccs
# Out:
#      area_code  fips_state  county  state    FIPS  vaccines
# 0        10100          92      58     92   92058     17521
# 1        10140          53      27     53   53027     32982
# 2        10180         144     753    144  144753         0
# 3        10220          40     123     40   40123     14142
# 4        10300          26      91     26   26091     37788
# ..         ...         ...     ...    ...     ...       ...
# 927      49700          12     216     12   12216     62086
# 928      49740           4      27      4    4027     97902
# 929      49780          39     119     39   39119     32476
# 930      49820          48     505     48   48505         0
# 931      71650         249     147    225  225147   4244868
#
# [932 rows x 6 columns]

# %%
# Merge vaccinations with the rest of the dataset
vaccs = pd.merge(merged2, vaccs[['area_code','vaccines']], on='area_code', how='left')
vaccs['vaccines_by_pop'] = vaccs['vaccines'] / vaccs['total_pop']
vaccs
# Out:
#      area_code  hispanic  white_nonhispanic  black_nonhispanic  \
# 0      10180.0     24.12              63.99               7.49
# 1      10420.0      2.22              79.34              12.49
# 2      10500.0      3.12              41.22              55.03
# 3      10540.0      9.52              84.34               0.60
# 4      10580.0      5.42              79.32               8.20
# ..         ...       ...                ...                ...
# 364    49620.0      8.08              82.62               5.79
# 365    49660.0      4.47              83.14               9.36
# 366    49700.0     30.65              48.98               2.82
# 367    49740.0     64.61              30.15               1.86
# 368    71650.0     11.59              70.11               6.78
#
#      other_nonhispanic  asian_nonhispanic   above_65  prepandemic_growth  \
# 0                 2.46               1.94  15.271998            0.061584
# 1                 2.48               3.47  18.158182            0.008289
# 2                 1.45               1.25  16.949280            0.027823
# 3                 4.20               1.34  19.069126            0.106132
# 4                 2.53               4.53  17.980738            0.033501
# ..                 ...                ...        ...                 ...
# 364               2.02               1.49  17.954696            0.040929
# 365               2.02               1.01  21.324866           -0.040301
# 366               5.18              12.37  14.441553            0.132029
# 367               2.10               1.28  19.319229            0.086792
# 368               2.08               9.45  15.958125            0.063666
#
#      leisure_by_emp  total_emp_feb2020  ...  pop_by_metro     state_name  \
# 0          0.111297               71.2  ...      172060.0          Texas
# 1          0.096521              336.5  ...      703479.0           Ohio
# 2               NaN               62.2  ...      146726.0        Georgia
# 3          0.079524               46.6  ...      129749.0         Oregon
# 4          0.082655              466.1  ...      880381.0       New York
# ..              ...                ...  ...           ...            ...
# 364        0.084918              185.4  ...      449058.0   Pennsylvania
# 365        0.109646              215.3  ...      536081.0           Ohio
# 366        0.098186               44.6  ...      175639.0     California
# 367        0.106338               59.1  ...      213787.0        Arizona
# 368        0.093706             2767.7  ...           NaN  Massachusetts
#
#      StringencyIndex  GovernmentResponseIndex  ContainmentHealthIndex  \
# 0          53.639829                52.692697               54.371357
# 1          58.787620                59.645174               62.129232
# 2          55.921999                56.254949               55.945863
# 3          60.793028                59.832710               58.962529
# 4          66.881749                71.821582               68.375444
# ..               ...                      ...                     ...
# 364        55.666169                59.711847               59.995945
# 365        58.787620                59.645174               62.129232
# 366        63.051351                67.141762               64.823398
# 367        52.612700                54.854439               55.531136
# 368        62.509786                62.408832               65.276183
#
#      EconomicSupportIndex   deaths  deaths_by_pop  vaccines  vaccines_by_pop
# 0               40.948421    511.0       0.002970         0         0.000000
# 1               42.263105   1231.0       0.001750    333431         0.473974
# 2               58.414579    499.0       0.003401     17340         0.118179
# 3               66.683468     81.0       0.000624     53524         0.412520
# 4               95.937500    892.0       0.001013    516496         0.586673
# ..                    ...      ...            ...       ...              ...
# 364             57.721774    826.0       0.001839    200064         0.445519
# 365             42.263105   1367.0       0.002081    299053         0.455314
# 366             80.771169    165.0       0.000939     62086         0.353486
# 367             50.730847    848.0       0.003967     97902         0.457942
# 368             42.347950  14836.0       0.002075   4244868         0.593691
#
# [369 rows x 44 columns]

# %% [markdown]
# ## Income

# %% [markdown]
# Personal median income data is sourced for the year 2019 at the MSA level from the Bureau of Economic Analysis (BEA) as available here: https://www.bea.gov/data/income-saving/personal-income-county-metro-and-other-areas.

# %%
# Add personal median income for each MSA
change_dir('output//stage2')
income = pd.read_csv('bea.csv')
income['income'] = income['income'].astype(int)
merged3 = vaccs.merge(income, on=['CBSA Title'],how='left').drop_duplicates()
merged3
# Out:
#      area_code  hispanic  white_nonhispanic  black_nonhispanic  \
# 0      10180.0     24.12              63.99               7.49
# 1      10420.0      2.22              79.34              12.49
# 2      10500.0      3.12              41.22              55.03
# 3      10540.0      9.52              84.34               0.60
# 4      10580.0      5.42              79.32               8.20
# ..         ...       ...                ...                ...
# 364    49620.0      8.08              82.62               5.79
# 365    49660.0      4.47              83.14               9.36
# 366    49700.0     30.65              48.98               2.82
# 367    49740.0     64.61              30.15               1.86
# 368    71650.0     11.59              70.11               6.78
#
#      other_nonhispanic  asian_nonhispanic   above_65  prepandemic_growth  \
# 0                 2.46               1.94  15.271998            0.061584
# 1                 2.48               3.47  18.158182            0.008289
# 2                 1.45               1.25  16.949280            0.027823
# 3                 4.20               1.34  19.069126            0.106132
# 4                 2.53               4.53  17.980738            0.033501
# ..                 ...                ...        ...                 ...
# 364               2.02               1.49  17.954696            0.040929
# 365               2.02               1.01  21.324866           -0.040301
# 366               5.18              12.37  14.441553            0.132029
# 367               2.10               1.28  19.319229            0.086792
# 368               2.08               9.45  15.958125            0.063666
#
#      leisure_by_emp  total_emp_feb2020  ...     state_name  StringencyIndex  \
# 0          0.111297               71.2  ...          Texas        53.639829
# 1          0.096521              336.5  ...           Ohio        58.787620
# 2               NaN               62.2  ...        Georgia        55.921999
# 3          0.079524               46.6  ...         Oregon        60.793028
# 4          0.082655              466.1  ...       New York        66.881749
# ..              ...                ...  ...            ...              ...
# 364        0.084918              185.4  ...   Pennsylvania        55.666169
# 365        0.109646              215.3  ...           Ohio        58.787620
# 366        0.098186               44.6  ...     California        63.051351
# 367        0.106338               59.1  ...        Arizona        52.612700
# 368        0.093706             2767.7  ...  Massachusetts        62.509786
#
#      GovernmentResponseIndex  ContainmentHealthIndex  EconomicSupportIndex  \
# 0                  52.692697               54.371357             40.948421
# 1                  59.645174               62.129232             42.263105
# 2                  56.254949               55.945863             58.414579
# 3                  59.832710               58.962529             66.683468
# 4                  71.821582               68.375444             95.937500
# ..                       ...                     ...                   ...
# 364                59.711847               59.995945             57.721774
# 365                59.645174               62.129232             42.263105
# 366                67.141762               64.823398             80.771169
# 367                54.854439               55.531136             50.730847
# 368                62.408832               65.276183             42.347950
#
#       deaths  deaths_by_pop  vaccines  vaccines_by_pop  income
# 0      511.0       0.002970         0         0.000000   26603
# 1     1231.0       0.001750    333431         0.473974   51095
# 2      499.0       0.003401     17340         0.118179   39922
# 3       81.0       0.000624     53524         0.412520   44830
# 4      892.0       0.001013    516496         0.586673   60767
# ..       ...            ...       ...              ...     ...
# 364    826.0       0.001839    200064         0.445519   51585
# 365   1367.0       0.002081    299053         0.455314   43167
# 366    165.0       0.000939     62086         0.353486   45782
# 367    848.0       0.003967     97902         0.457942   36570
# 368  14836.0       0.002075   4244868         0.593691   81498
#
# [369 rows x 45 columns]

# %% [markdown]
# ## Finalizing

# %%
merged3.columns
# Out:
# Index(['area_code', 'hispanic', 'white_nonhispanic', 'black_nonhispanic',
#        'other_nonhispanic', 'asian_nonhispanic', 'above_65',
#        'prepandemic_growth', 'leisure_by_emp', 'total_emp_feb2020',
#        'manufacturing_emp_feb2020', 'service_emp_feb2020', 'total_emp_jun2021',
#        'manufacturing_emp_jun2021', 'service_emp_jun2021', 'total_employment',
#        'manufacturing', 'service', 'emp_tot_change_feb2020_jun2021',
#        'manufacturing_change_feb2020_jun2021',
#        'service_change_feb2020_jun2021', 'occ_15', 'total_pop', 'pop_excl',
#        'less_than_9grade', 'hs_nodiploma', 'ged', 'college_nodegree',
#        'associates', 'bachelors_graduate', 'CBSA Title', 'division', 'region',
#        'state', 'pop_by_metro', 'state_name', 'StringencyIndex',
#        'GovernmentResponseIndex', 'ContainmentHealthIndex',
#        'EconomicSupportIndex', 'deaths', 'deaths_by_pop', 'vaccines',
#        'vaccines_by_pop', 'income'],
#       dtype='object')

# %%
merged3 = merged3[['area_code','CBSA Title','state_name','state','division','region','total_pop','pop_by_metro','income','hispanic', 'white_nonhispanic',
                   'black_nonhispanic','other_nonhispanic', 'asian_nonhispanic', 'above_65', 'less_than_9grade', 'hs_nodiploma', 
                   'ged', 'college_nodegree','associates', 'bachelors_graduate','total_emp_feb2020','manufacturing_emp_feb2020', 
                   'service_emp_feb2020', 'total_emp_jun2021','manufacturing_emp_jun2021', 'service_emp_jun2021', 'total_employment',
                   'manufacturing', 'service', 'emp_tot_change_feb2020_jun2021','manufacturing_change_feb2020_jun2021','service_change_feb2020_jun2021', 
                   'occ_15','leisure_by_emp','prepandemic_growth','StringencyIndex','GovernmentResponseIndex', 'ContainmentHealthIndex',
                   'EconomicSupportIndex', 'deaths', 'deaths_by_pop', 'vaccines','vaccines_by_pop']]
merged3
# Out:
#      area_code                         CBSA Title     state_name  state  \
# 0      10180.0                        Abilene, TX          Texas     48
# 1      10420.0                          Akron, OH           Ohio     39
# 2      10500.0                         Albany, GA        Georgia     13
# 3      10540.0                         Albany, OR         Oregon     41
# 4      10580.0        Albany-Schenectady-Troy, NY       New York     36
# ..         ...                                ...            ...    ...
# 364    49620.0                   York-Hanover, PA   Pennsylvania     42
# 365    49660.0  Youngstown-Warren-Boardman, OH-PA           Ohio     39
# 366    49700.0                      Yuba City, CA     California      6
# 367    49740.0                           Yuma, AZ        Arizona      4
# 368    71650.0     Boston-Cambridge-Nashua, MA-NH  Massachusetts     25
#
#                         division            region  total_pop  pop_by_metro  \
# 0    West South Central Division      South Region     172060      172060.0
# 1    East North Central Division    Midwest Region     703479      703479.0
# 2        South Atlantic Division      South Region     146726      146726.0
# 3               Pacific Division       West Region     129749      129749.0
# 4       Middle Atlantic Division  Northeast Region     880381      880381.0
# ..                           ...               ...        ...           ...
# 364     Middle Atlantic Division  Northeast Region     449058      449058.0
# 365  East North Central Division    Midwest Region     656806      536081.0
# 366             Pacific Division       West Region     175639      175639.0
# 367            Mountain Division       West Region     213787      213787.0
# 368         New England Division  Northeast Region    7149963           NaN
#
#      income  hispanic  ...  leisure_by_emp  prepandemic_growth  \
# 0     26603     24.12  ...        0.111297            0.061584
# 1     51095      2.22  ...        0.096521            0.008289
# 2     39922      3.12  ...             NaN            0.027823
# 3     44830      9.52  ...        0.079524            0.106132
# 4     60767      5.42  ...        0.082655            0.033501
# ..      ...       ...  ...             ...                 ...
# 364   51585      8.08  ...        0.084918            0.040929
# 365   43167      4.47  ...        0.109646           -0.040301
# 366   45782     30.65  ...        0.098186            0.132029
# 367   36570     64.61  ...        0.106338            0.086792
# 368   81498     11.59  ...        0.093706            0.063666
#
#      StringencyIndex  GovernmentResponseIndex  ContainmentHealthIndex  \
# 0          53.639829                52.692697               54.371357
# 1          58.787620                59.645174               62.129232
# 2          55.921999                56.254949               55.945863
# 3          60.793028                59.832710               58.962529
# 4          66.881749                71.821582               68.375444
# ..               ...                      ...                     ...
# 364        55.666169                59.711847               59.995945
# 365        58.787620                59.645174               62.129232
# 366        63.051351                67.141762               64.823398
# 367        52.612700                54.854439               55.531136
# 368        62.509786                62.408832               65.276183
#
#      EconomicSupportIndex   deaths  deaths_by_pop  vaccines  vaccines_by_pop
# 0               40.948421    511.0       0.002970         0         0.000000
# 1               42.263105   1231.0       0.001750    333431         0.473974
# 2               58.414579    499.0       0.003401     17340         0.118179
# 3               66.683468     81.0       0.000624     53524         0.412520
# 4               95.937500    892.0       0.001013    516496         0.586673
# ..                    ...      ...            ...       ...              ...
# 364             57.721774    826.0       0.001839    200064         0.445519
# 365             42.263105   1367.0       0.002081    299053         0.455314
# 366             80.771169    165.0       0.000939     62086         0.353486
# 367             50.730847    848.0       0.003967     97902         0.457942
# 368             42.347950  14836.0       0.002075   4244868         0.593691
#
# [369 rows x 44 columns]

# %%
change_dir('output//stage2')
merged3.to_csv('final_output.csv',index="ignore")
